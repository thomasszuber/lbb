# %%
import pandas as pd
from itertools import combinations, combinations_with_replacement
import numpy as np
import csv
import operator

# %%
# Load Data 

data = pd.read_csv("rome_tension.csv")

# Define tree

data.sort_values(by=['rome1','rome3','rome5'])
cat = data.drop(columns=['BE_id','T']).drop_duplicates()
tree1 = dict(cat.groupby(by='rome1')['rome3'].unique())
tree3 = dict(cat.groupby(by='rome3')['rome5'].unique())
tree = {key1:{key3:list(tree3[key3]) for key3 in tree1[key1]} for key1 in tree1.keys()}

# Delete these groups: they are too big!! 
#del tree['H']
#del tree['K']
#del tree['N']

# %%
def objective(x,y): 
    return (x-y)**2
    #return x + y

# groups class
class Group:
    def __init__(self,nodes):
        self.nodes = nodes 
        self.nb_nodes = len(nodes)
        self.nodes_type = len(self.nodes[0])
        if self.nodes_type > 1: self.branch = self.nodes[0][0]
        else: self.branch = ''
        if self.nodes_type == 5: 
            self.splitable = self.nb_nodes > 1
            self.breakable = False
            self.contains = self.nodes
            self.terminal = self.contains
            self.size = len(self.contains)
        if self.nodes_type == 3:
            self.contains = []
            for node in self.nodes:
                self.contains += tree[self.branch][node]
            self.terminal = self.contains
            self.size = len(self.contains)
            self.splitable = self.nb_nodes > 1
            self.breakable = self.nb_nodes == 1 and self.size > 1
        if self.nodes_type == 1:
            self.contains = []
            for node in self.nodes:
                self.contains += list(tree[node].keys())
            self.size = len(self.contains)
            self.terminal = []
            for key in self.contains: 
                self.terminal += tree[key[0]][key]
            self.splitable = self.nb_nodes > 1
            self.breakable = self.nb_nodes == 1 and self.size > 1
        self.var = data.loc[data['rome5'].isin(self.terminal)]['T'].var()
                
    def split(self):
        
        if self.nodes_type in [1,3]:
            
            if self.splitable:
                n = self.nb_nodes
                if n % 2 == 0: k = n // 2
                else: k = (n-1) // 2
                if k == 1: gen_splits = ([x[0]] for x in combinations(self.nodes,k))
                else: gen_splits = (list(x) for x in combinations(self.nodes,k))
                sig = float('Inf')
                for split in gen_splits:
                    g1 = Group(split)
                    g2 = Group([key for key in self.nodes if key not in split])
                    ob  = objective(g2.var,g1.var)
                    if ob < sig:
                        sig = ob
                        best_g1, best_g2 = g1, g2
                return [best_g1, best_g2]
            
            if self.breakable:    
                n = self.size
                if n % 2 == 0: k = n // 2
                else: k = (n-1) // 2
                if k == 1: gen_splits = ([x[0]] for x in combinations(self.contains,k))
                else: gen_splits = (list(x) for x in combinations(self.contains,k))
                sig = float('Inf')
                for split in gen_splits:
                    g1 = Group(split)
                    g2 = Group([key for key in self.contains if key not in split])
                    ob  = objective(g2.var,g1.var)
                    if ob < sig:
                        sig = ob
                        best_g1, best_g2 = g1, g2
                return [best_g1, best_g2]
        
        if self.nodes_type == 5:
            
            if self.splitable:
                n = self.nb_nodes
                if n % 2 == 0: k = n // 2
                else: k = (n-1) // 2
                if k == 1: gen_splits = ([x[0]] for x in combinations(self.nodes,k))
                else: gen_splits = (list(x) for x in combinations(self.nodes,k))
                sig = float('Inf')
                for split in gen_splits:
                    g1 = Group(split)
                    g2 = Group([key for key in self.nodes if key not in split])
                    ob  = objective(g2.var,g1.var)
                    if ob < sig:
                        sig = ob
                        best_g1, best_g2 = g1, g2
                return [best_g1, best_g2]

        if self.splitable == False and self.breakable == False:
            print(f'{self.nodes} is unbreakable.')
            return self, []
            
def order_groups(groups):
    ordered_groups = sorted([[group,group.var] for group in groups], key=operator.itemgetter(1), reverse = True)
    return [group[0] for group in ordered_groups]

# %% [markdown]
# ### Selecting biggest variance in each split:

# %%
final_groups1 = {}
j = 0
for key1, keys3 in tree.items():
    groups = order_groups([Group(list(keys3.keys()))])
    G = len(keys3)
    g = len(groups)
    while g < G:
        i , split = 0, False
        while i < len(groups) and split == False:
            if groups[i].splitable or groups[i].breakable:
                print(f'Spliting {groups[i].nodes}')
                groups = order_groups(groups[:i] + groups[i].split() + groups[i+1:])
                split = True
            else:
                i += 1
        if split == False:
            print(f'Impossible to split or break group anymore: only {g} out of {G} groups created')
            g = G
        else:
            g += 1
    for group in groups:
        j += 1
        final_groups1[f'g{j}'] = group.terminal
# Out:
# Spliting ['A11', 'A12', 'A13', 'A14', 'A15']
# Spliting ['A13', 'A14', 'A15']
# Spliting ['A13']
# Spliting ['A1301', 'A1302']
# Spliting ['B11', 'B12', 'B13', 'B14', 'B15', 'B16', 'B17', 'B18']
# Spliting ['B13', 'B15', 'B16', 'B18']
# Spliting ['B13', 'B16']
# Spliting ['B16']
# Spliting ['B1602', 'B1604']
# Spliting ['B1601', 'B1603']
# Spliting ['B13']
# Spliting ['C11', 'C12', 'C13', 'C14', 'C15']
# Spliting ['C11', 'C12', 'C13']
# Spliting ['C11', 'C12']
# Spliting ['C11']
# Spliting ['D11', 'D12', 'D13', 'D14', 'D15']
# Spliting ['D11', 'D12', 'D15']
# Spliting ['D12', 'D15']
# Spliting ['D15']
# Spliting ['E11', 'E12', 'E13', 'E14']
# Spliting ['E12', 'E13']
# Spliting ['E13']
# Spliting ['F11', 'F12', 'F13', 'F14', 'F15', 'F16', 'F17']
# Spliting ['F11', 'F12', 'F14', 'F16']
# Spliting ['F11', 'F12']
# Spliting ['F12']
# Spliting ['F1203', 'F1204']
# Spliting ['F11']
# Spliting ['G11', 'G12', 'G13', 'G14', 'G15', 'G16', 'G17', 'G18']
# Spliting ['G12', 'G13', 'G14', 'G17']
# Spliting ['G13', 'G14']
# Spliting ['G13']
# Spliting ['G1301', 'G1302']
# Spliting ['G12', 'G17']
# Spliting ['G17']
# Spliting ['H11', 'H12', 'H13', 'H14', 'H15', 'H21', 'H22', 'H23', 'H24', 'H25', 'H26', 'H27', 'H28', 'H29', 'H31', 'H32', 'H33', 'H34']
# Spliting ['H22', 'H23', 'H24', 'H25', 'H26', 'H27', 'H28', 'H31', 'H34']
# Spliting ['H22', 'H23', 'H25', 'H26', 'H34']
# Spliting ['H22', 'H25', 'H34']
# Spliting ['H25', 'H34']
# Spliting ['H34']
# Spliting ['H3402', 'H3403']
# Spliting ['H25']
# Spliting ['H2501', 'H2503', 'H2505']
# Spliting ['H2501', 'H2503']
# Spliting ['H23', 'H26']
# Spliting ['H22']
# Spliting ['H2201', 'H2203', 'H2204', 'H2205', 'H2208']
# Spliting ['H2201', 'H2204', 'H2205']
# Spliting ['H2204', 'H2205']
# Spliting ['H26']
# Spliting ['H2601', 'H2603', 'H2605']
# Spliting ['I11', 'I12', 'I13', 'I14', 'I15', 'I16']
# Spliting ['I11', 'I13', 'I15']
# Spliting ['I11', 'I15']
# Spliting ['I15']
# Spliting ['I1501', 'I1503']
# Spliting ['J11', 'J12', 'J13', 'J14', 'J15']
# Spliting ['J11', 'J14', 'J15']
# Spliting ['J11', 'J14']
# Spliting ['J14']
# Spliting ['K11', 'K12', 'K13', 'K14', 'K15', 'K16', 'K17', 'K18', 'K19', 'K21', 'K22', 'K23', 'K24', 'K25', 'K26']
# Spliting ['K11', 'K14', 'K15', 'K17', 'K19', 'K21', 'K23', 'K26']
# Spliting ['K19', 'K21', 'K23', 'K26']
# Spliting ['K19', 'K23']
# Spliting ['K23']
# Spliting ['K2302', 'K2304', 'K2305']
# Spliting ['K2302', 'K2305']
# Spliting ['K2301', 'K2303', 'K2306']
# Spliting ['K2301', 'K2306']
# Spliting ['K19']
# Spliting ['K1901', 'K1904']
# Spliting ['K11', 'K14', 'K15', 'K17']
# Spliting ['K14', 'K17']
# Spliting ['K14']
# Spliting ['L11', 'L12', 'L13', 'L14', 'L15']
# Spliting ['L11', 'L13', 'L15']
# Spliting ['L11', 'L15']
# Spliting ['L11']
# Spliting ['M11', 'M12', 'M13', 'M14', 'M15', 'M16', 'M17', 'M18']
# Spliting ['M12', 'M14', 'M17', 'M18']
# Spliting ['M12', 'M18']
# Spliting ['M18']
# Spliting ['M1802', 'M1804', 'M1806', 'M1807', 'M1809']
# Spliting ['M1802', 'M1804', 'M1806']
# Spliting ['M1802', 'M1804']
# Spliting ['N11', 'N12', 'N13', 'N21', 'N22', 'N31', 'N32', 'N41', 'N42', 'N43', 'N44']
# Spliting ['N22', 'N31', 'N32', 'N42', 'N43', 'N44']
# Spliting ['N22', 'N42', 'N44']
# Spliting ['N42', 'N44']
# Spliting ['N44']
# Spliting ['N4401', 'N4402']
# Spliting ['N42']
# Spliting ['N4202', 'N4204']
# Spliting ['N4201', 'N4203']
# Spliting ['N31', 'N32', 'N43']

# %% [markdown]
# #### Saving output

# %%
final_output = {}
i = 0
for key, group in final_groups1.items():
    for rome in group:
        final_output[rome] = key[1:]
with open('optimal_grouping_fresh1.csv', 'w') as csv_file:
    writer = csv.writer(csv_file)
    for key, value in final_output.items():
       writer.writerow([key, value])

# %% [markdown]
# ### Trying all possible splits:

# %%
final_groups2 = {}
j = 0
for key1, keys3 in tree.items():
    groups = order_groups([Group(list(keys3.keys()))])
    G = len(keys3)
    g = len(groups)
    while g < G:
        i, sig, split = 0, float('Inf'), False
        while i < len(groups):
            if groups[i].splitable or groups[i].breakable:
                new_groups = order_groups(groups[:i] + groups[i].split() + groups[i+1:])
                var = sum([group.var for group in new_groups])
                if var < sig:
                    split = True
                    sig = var
                    best_groups = new_groups
                    i_best = i 
                i += 1
            else:
                i += 1
        if split == False:
            print(f'Impossible to split or break group anymore: only {g} out of {G} groups created')
            g = G
        else:
            g += 1
            print(f'Best split: {groups[i_best].nodes}')
            groups = best_groups 
    for group in groups:
        j += 1
        final_groups2[f'g{j}'] = group.terminal
# Out:
# Best split: ['A11', 'A12', 'A13', 'A14', 'A15']
# Best split: ['A11', 'A13']
# Best split: ['A12', 'A14', 'A15']
# Best split: ['A14']
# Best split: ['B11', 'B12', 'B13', 'B14', 'B15', 'B16', 'B17', 'B18']
# Best split: ['B11', 'B16', 'B17', 'B18']
# Best split: ['B17', 'B18']
# Best split: ['B11', 'B16']
# Best split: ['B18']
# Best split: ['B1801', 'B1805', 'B1806']
# Best split: ['B1801', 'B1806']
# Best split: ['C11', 'C12', 'C13', 'C14', 'C15']
# Best split: ['C11', 'C15']
# Best split: ['C15']
# Best split: ['C1503', 'C1504']
# Best split: ['D11', 'D12', 'D13', 'D14', 'D15']
# Best split: ['D12', 'D14']
# Best split: ['D14']
# Best split: ['D1404', 'D1406', 'D1407', 'D1408']
# Best split: ['E11', 'E12', 'E13', 'E14']
# Best split: ['E11', 'E13']
# Best split: ['E11']
# Best split: ['F11', 'F12', 'F13', 'F14', 'F15', 'F16', 'F17']
# Best split: ['F11', 'F13', 'F17']
# Best split: ['F11', 'F13']
# Best split: ['F13']
# Best split: ['F17']
# Best split: ['F1701', 'F1704', 'F1706']
# Best split: ['G11', 'G12', 'G13', 'G14', 'G15', 'G16', 'G17', 'G18']
# Best split: ['G15', 'G16', 'G17', 'G18']
# Best split: ['G15', 'G18']
# Best split: ['G18']
# Best split: ['G1801', 'G1802']
# Best split: ['G11', 'G12', 'G13', 'G14']
# Best split: ['G11', 'G14']
# Best split: ['H11', 'H12', 'H13', 'H14', 'H15', 'H21', 'H22', 'H23', 'H24', 'H25', 'H26', 'H27', 'H28', 'H29', 'H31', 'H32', 'H33', 'H34']
# Best split: ['H11', 'H12', 'H13', 'H14', 'H21', 'H24', 'H28', 'H29', 'H31']
# Best split: ['H11', 'H13', 'H14', 'H24']
# Best split: ['H12', 'H21', 'H28', 'H29', 'H31']
# Best split: ['H12', 'H21', 'H29']
# Best split: ['H21']
# Best split: ['H28', 'H31']
# Best split: ['H31']
# Best split: ['H11', 'H14']
# Best split: ['H11']
# Best split: ['H14']
# Best split: ['H1403', 'H1404']
# Best split: ['H12', 'H29']
# Best split: ['H29']
# Best split: ['H2902', 'H2905', 'H2906', 'H2907', 'H2910', 'H2911', 'H2914']
# Best split: ['H2906', 'H2910', 'H2911']
# Best split: ['H2906', 'H2910']
# Best split: ['I11', 'I12', 'I13', 'I14', 'I15', 'I16']
# Best split: ['I11', 'I12', 'I16']
# Best split: ['I12']
# Best split: ['I1201', 'I1203']
# Best split: ['I13', 'I14', 'I15']
# Best split: ['J11', 'J12', 'J13', 'J14', 'J15']
# Best split: ['J13', 'J14']
# Best split: ['J13']
# Best split: ['J1301', 'J1305', 'J1306', 'J1307']
# Best split: ['K11', 'K12', 'K13', 'K14', 'K15', 'K16', 'K17', 'K18', 'K19', 'K21', 'K22', 'K23', 'K24', 'K25', 'K26']
# Best split: ['K11', 'K12', 'K15', 'K16', 'K17', 'K18', 'K24']
# Best split: ['K11', 'K15', 'K18']
# Best split: ['K15', 'K18']
# Best split: ['K18']
# Best split: ['K15']
# Best split: ['K1501', 'K1502', 'K1504']
# Best split: ['K1503', 'K1505']
# Best split: ['K1501', 'K1502']
# Best split: ['K12', 'K16', 'K17', 'K24']
# Best split: ['K12', 'K17']
# Best split: ['K12']
# Best split: ['K1201', 'K1202', 'K1205', 'K1206']
# Best split: ['K1201', 'K1202']
# Best split: ['L11', 'L12', 'L13', 'L14', 'L15']
# Best split: ['L12', 'L14', 'L15']
# Best split: ['L14', 'L15']
# Best split: ['L12']
# Best split: ['M11', 'M12', 'M13', 'M14', 'M15', 'M16', 'M17', 'M18']
# Best split: ['M11', 'M13', 'M15', 'M17']
# Best split: ['M13', 'M17']
# Best split: ['M13']
# Best split: ['M11', 'M15']
# Best split: ['M15']
# Best split: ['M1501', 'M1502']
# Best split: ['N11', 'N12', 'N13', 'N21', 'N22', 'N31', 'N32', 'N41', 'N42', 'N43', 'N44']
# Best split: ['N22', 'N31', 'N41', 'N42', 'N43']
# Best split: ['N11', 'N12', 'N13', 'N21', 'N32', 'N44']
# Best split: ['N12', 'N13', 'N32']
# Best split: ['N32']
# Best split: ['N3201', 'N3202']
# Best split: ['N22', 'N31']
# Best split: ['N22']
# Best split: ['N2203', 'N2205']
# Best split: ['N2201', 'N2202', 'N2204']

# %%
final_output = {}
i = 0
for key, group in final_groups2.items():
    for rome in group:
        final_output[rome] = key[1:]
with open('groups_min_dist_no_realloc.csv', 'w') as csv_file:
    writer = csv.writer(csv_file)
    for key, value in final_output.items():
       writer.writerow([key, value])

# %% [markdown]
# ### Introducing top level allocation:

# %%
final_groups3 = {}
j = 0
groups = [Group(list(tree.keys()))]
G = sum([len(tree[key].values()) for key in tree.keys()])
g = len(groups)
while g < G:
    i, sig, split = 0, float('Inf'), False
    while i < len(groups):
        if groups[i].splitable or groups[i].breakable:
            new_groups = groups[:i] + groups[i].split() + groups[i+1:]
            var = sum([group.var for group in new_groups])
            if var < sig:
                split = True
                sig = var
                best_groups = new_groups
                i_best = i 
            i += 1
        else:
            i += 1
    if split == False:
        print(f'Impossible to split or break group anymore: only {g} out of {G} groups created')
        g = G
    else:
        g += 1
        print(f'Created {g}/{G} nodes. Last best split: {groups[i_best].nodes}.')
        groups = best_groups 
for group in groups:
    j += 1
    final_groups3[f'g{j}'] = group.terminal
# Out:
# Best split: ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'M', 'N']
# Best split: ['A', 'D', 'E', 'F', 'G', 'I', 'M']
# Best split: ['D', 'F', 'G']
# Best split: ['D']
# Best split: ['D13', 'D14']
# Best split: ['D14']
# Best split: ['D1401', 'D1402', 'D1403', 'D1407']
# Best split: ['D1401', 'D1407']
# Best split: ['D1402', 'D1403']
# Best split: ['D1404', 'D1405', 'D1406', 'D1408']
# Best split: ['D1404', 'D1406']
# Best split: ['D11', 'D12', 'D15']
# Best split: ['D11']
# Best split: ['D1101', 'D1102', 'D1104']
# Best split: ['D1101', 'D1104']
# Best split: ['D1405', 'D1408']
# Best split: ['D1103', 'D1105', 'D1106', 'D1107']
# Best split: ['D1105', 'D1106']
# Best split: ['D1103', 'D1107']
# Best split: ['D12', 'D15']
# Best split: ['D12']
# Best split: ['D1202', 'D1208', 'D1209', 'D1211', 'D1212', 'D1213', 'D1214']
# Best split: ['D1202', 'D1212', 'D1214']
# Best split: ['D1202', 'D1212']
# Best split: ['D1208', 'D1209', 'D1211', 'D1213']
# Best split: ['D1208', 'D1211']
# Best split: ['D1209', 'D1213']
# Best split: ['D15']
# Best split: ['D1502', 'D1503', 'D1505', 'D1507']
# Best split: ['D1505', 'D1507']
# Best split: ['D1502', 'D1503']
# Best split: ['F', 'G']
# Best split: ['G']
# Best split: ['G11', 'G15', 'G16', 'G18']
# Best split: ['G11', 'G16']
# Best split: ['G16']
# Best split: ['G1603', 'G1605']
# Best split: ['G1601', 'G1602', 'G1604']
# Best split: ['G1601', 'G1604']
# Best split: ['G11']
# Best split: ['G15', 'G18']
# Best split: ['G15']
# Best split: ['G18']
# Best split: ['G1802', 'G1803']
# Best split: ['F']
# Best split: ['F13', 'F15', 'F17']
# Best split: ['F13']
# Best split: ['F15', 'F17']
# Best split: ['F15']
# Best split: ['F17']
# Best split: ['F1701', 'F1702', 'F1703']
# Best split: ['F1704', 'F1705', 'F1706']
# Best split: ['F1701', 'F1702']
# Best split: ['F1501', 'F1502']
# Best split: ['F11', 'F12', 'F14', 'F16']
# Best split: ['A', 'E', 'I', 'M']
# Best split: ['D1501', 'D1504', 'D1506', 'D1508', 'D1509']
# Best split: ['D1501', 'D1504']
# Best split: ['I', 'M']
# Best split: ['M']
# Best split: ['M11', 'M13', 'M15', 'M16']
# Best split: ['M13', 'M15']
# Best split: ['M15']
# Best split: ['M13']
# Best split: ['M1502', 'M1503']
# Best split: ['M11', 'M16']
# Best split: ['M16']
# Best split: ['M1604', 'M1605', 'M1607', 'M1608']
# Best split: ['M1607', 'M1608']
# Best split: ['M1604', 'M1605']
# Best split: ['M1601', 'M1602', 'M1603', 'M1606', 'M1609']
# Best split: ['M1601', 'M1602']
# Best split: ['M1603', 'M1606', 'M1609']
# Best split: ['M1603', 'M1606']
# Best split: ['M11']
# Best split: ['I']
# Best split: ['I12', 'I14', 'I16']
# Best split: ['I14']
# Best split: ['I12', 'I16']
# Best split: ['I12']
# Best split: ['I16']
# Best split: ['I1603', 'I1604', 'I1606']
# Best split: ['I1603', 'I1606']
# Best split: ['A', 'E']
# Best split: ['A']
# Best split: ['A11', 'A12']
# Best split: ['A12']
# Best split: ['A1202', 'A1203']
# Best split: ['A1201', 'A1204', 'A1205']
# Best split: ['A13', 'A14', 'A15']
# Best split: ['A13']
# Best split: ['G1801', 'G1804']
# Best split: ['E']
# Best split: ['A14', 'A15']
# Best split: ['A14']
# Best split: ['A1401', 'A1402', 'A1403', 'A1407', 'A1408', 'A1413', 'A1414', 'A1416']
# Best split: ['A1401', 'A1402', 'A1403', 'A1408']
# Best split: ['A1401', 'A1402']
# Best split: ['A1403', 'A1408']
# Best split: ['A1407', 'A1413', 'A1414', 'A1416']
# Best split: ['A1414', 'A1416']
# Best split: ['A1404', 'A1405', 'A1406', 'A1409', 'A1410', 'A1411', 'A1412', 'A1415', 'A1417']
# Best split: ['A1406', 'A1411', 'A1415', 'A1417']
# Best split: ['A1406', 'A1417']
# Best split: ['A15']
# Best split: ['A1501', 'A1504']
# Best split: ['A1411', 'A1415']
# Best split: ['E12', 'E13']
# Best split: ['E12']

# %%
final_output = {}
i = 0
for key, group in final_groups3.items():
    for rome in group:
        final_output[rome] = key[1:]
with open('optimal_grouping_fresh3.csv', 'w') as csv_file:
    writer = csv.writer(csv_file)
    for key, value in final_output.items():
       writer.writerow([key, value])

# %% [markdown]
# ### Merge to ROME arbo

# %%
def adjust(cat):
    if len(cat) == 1:
        cat = '0' + cat
        return cat

arbo = pd.read_csv("arbor_rome.csv")
arbo.columns = 'ind', 'div', 'cat', 'label', 'exp', 'int'
arbo = arbo.filter(items=['ind','div','cat','label'])
arbo = arbo.dropna(subset=['cat'],axis=0)
arbo['cat'] = arbo['cat'].apply(int).apply(str).apply(adjust)
arbo['div'] = arbo['div'].apply(int).apply(str)
arbo['rome'] = arbo['ind'] + arbo['div'] + arbo['cat']
arbo = arbo.drop_duplicates(subset='rome').dropna(subset=['rome'],axis=0).reset_index(drop=True)
arbo['rome3'] = arbo['ind'] + arbo['div']
arbo = arbo.filter(items=['ind','rome3','rome','label'])

# %%
name = 'groups_min_dist_no_realloc.csv'
results = pd.read_csv(name,header=None)
results.columns = 'rome', 'group'
results = pd.merge(results, arbo, on='rome', how='left')
results = results[['ind','rome3','rome','label','group']]
results = results.sort_values(by='group').reset_index(drop=True)
results.to_csv(name[:-4] + '_headings.csv',index=False)

# %%
results
# Out:
#      ind rome3   rome                                              label  \
# 0      A   A13  A1301     Conseil et assistance technique en agriculture
# 1      A   A13  A1302    Contrôle et diagnostic technique en agriculture
# 2      A   A13  A1303  Ingénierie en agriculture et environnement nat...
# 3      A   A14  A1403                Aide d'élevage agricole et aquacole
# 4      A   A14  A1409                     Élevage de lapins et volailles
# 5    NaN   NaN  A1410                                                NaN
# 6    NaN   NaN  A1411                                                NaN
# 7    NaN   NaN  A1412                                                NaN
# 8    NaN   NaN  A1414                                                NaN
# 9    NaN   NaN  A1415                                                NaN
# 10   NaN   NaN  A1416                                                NaN
# 11   NaN   NaN  A1417                                                NaN
# 12   NaN   NaN  A1413                                                NaN
# 13     A   A14  A1408         Élevage d'animaux sauvages ou de compagnie
# 14     A   A14  A1407                             Élevage bovin ou équin
# 15     A   A14  A1406                   Encadrement équipage de la pêche
# 16     A   A14  A1405                       Arboriculture et viticulture
# 17     A   A14  A1404                                        Aquaculture
# 18     A   A14  A1402  Aide agricole de production légumière ou végétale
# 19     A   A14  A1401  Aide agricole de production fruitière ou viticole
# 20     A   A12  A1201                            Bûcheronnage et élagage
# 21     A   A12  A1202                     Entretien des espaces naturels
# 22     A   A12  A1203                        Entretien des espaces verts
# 23     A   A12  A1204                   Protection du patrimoine naturel
# 24     A   A12  A1205                                       Sylviculture
# 25     A   A15  A1501                             Aide aux soins animaux
# 26     A   A15  A1502                                  Podologie animale
# 27     A   A15  A1503                             Toilettage des animaux
# 28     A   A15  A1504                                      Santé animale
# 29     A   A11  A1101          Conduite d'engins agricoles et forestiers
# ..   ...   ...    ...                                                ...
# 502    N   N44  N4401                        Circulation du réseau ferré
# 503    N   N44  N4403                          Manoeuvre du réseau ferré
# 504    N   N21  N2101                    Navigation commerciale aérienne
# 505    N   N11  N1103             Magasinage et préparation de commandes
# 506    N   N11  N1104  Manoeuvre et conduite d'engins lourds de manut...
# 507    N   N11  N1102                                       Déménagement
# 508    N   N11  N1101       Conduite d'engins de déplacement des charges
# 509    N   N11  N1105                    Manutention manuelle de charges
# 510    N   N32  N3201  Exploitation des opérations portuaires et du t...
# 511    N   N12  N1201                              Affrètement transport
# 512    N   N12  N1202  Gestion des opérations de circulation internat...
# 513    N   N13  N1301  Conception et organisation de la chaîne logist...
# 514    N   N13  N1302                       Direction de site logistique
# 515    N   N13  N1303   Intervention technique d'exploitation logistique
# 516    N   N43  N4302                  Contrôle des transports en commun
# 517    N   N43  N4301                                 Conduite sur rails
# 518    N   N42  N4204  Intervention technique d'exploitation des tran...
# 519    N   N42  N4203  Intervention technique d'exploitation des tran...
# 520    N   N42  N4202  Direction d'exploitation des transports routie...
# 521    N   N41  N4103          Conduite de transport en commun sur route
# 522    N   N41  N4105  Conduite et livraison par tournées sur courte ...
# 523    N   N41  N4104                      Courses et livraisons express
# 524    N   N41  N4102              Conduite de transport de particuliers
# 525    N   N41  N4101  Conduite de transport de marchandises sur long...
# 526    N   N42  N4201  Direction d'exploitation des transports routie...
# 527    N   N22  N2201                   Personnel d'escale aéroportuaire
# 528    N   N22  N2202                 Contrôle de la navigation aérienne
# 529    N   N22  N2205   Direction d'escale et exploitation aéroportuaire
# 530    N   N32  N3203                              Manutention portuaire
# 531    N   N32  N3202                  Exploitation du transport fluvial
#
#      group
# 0        1
# 1        1
# 2        1
# 3        2
# 4        2
# 5        2
# 6        2
# 7        2
# 8        2
# 9        2
# 10       2
# 11       3
# 12       3
# 13       3
# 14       3
# 15       3
# 16       3
# 17       3
# 18       3
# 19       3
# 20       4
# 21       4
# 22       4
# 23       4
# 24       4
# 25       4
# 26       4
# 27       4
# 28       4
# 29       5
# ..     ...
# 502    103
# 503    103
# 504    103
# 505    103
# 506    103
# 507    103
# 508    103
# 509    103
# 510    104
# 511    105
# 512    105
# 513    105
# 514    105
# 515    105
# 516    106
# 517    106
# 518    106
# 519    106
# 520    106
# 521    106
# 522    106
# 523    106
# 524    106
# 525    106
# 526    106
# 527    107
# 528    107
# 529    108
# 530    109
# 531    110
#
# [532 rows x 5 columns]
